# %% [markdown]
# <a href="https://colab.research.google.com/github/Subasri0415/Subasri-TNSF-C2TC-PYTHON-with-AIML/blob/main/Linear_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DSA in Python**

# %% [markdown]
# ## ***Linear Data Structures***

# %% [markdown]
# # Python Stacks
#
# A **Stack** is a linear data structure that follows the **LIFO (Last In, First Out)** principle. The element added last is the first one to be removed.
#
# ### Characteristics:
#
# * **LIFO Structure:** Access is limited to the top element.
# * **Push Operation:** Adding an element to the top of the stack.
# * **Pop Operation:** Removing the top element from the stack.
# * **Peek/Top Operation:** Viewing the top element without removing it.
#
# ---
#
# ### Core Operations:
#
# | Operation | Description |
# | :--- | :--- |
# | `append()` | Push an element onto the top of the stack |
# | `pop()` | Remove and return the top element |
# | `[-1]` | Peek at the top element without removing it |
# | `len()` | Check the total size of the stack |

# %% [markdown]
# Creating a Stack

# %%
# Initialize an empty stack using a Python list
stack = []

# %% [markdown]
# 1. append() - Push

# %%
# 1. Push elements onto the stack
stack.append(10)
stack.append(20)
stack.append(30)
print("Stack after pushes:", stack)  # Output: [10, 20, 30]
# Out:
# Stack after pushes: [10, 20, 30]

# %% [markdown]
# 2. [-1] - Peek

# %%
# 2. Peek at the top element
top_element = stack[-1]
print("Top element:", top_element)   # Output: 30
# Out:
# Top element: 30

# %% [markdown]
# 3. pop() - Remove

# %%
# 3. Pop element from the stack
popped = stack.pop()
print("Popped element:", popped)     # Output: 30
print("Stack after pop:", stack)     # Output: [10, 20]
# Out:
# Popped element: 30
# Stack after pop: [10, 20]

# %% [markdown]
# 4. len() - Size

# %%
# 4. Check stack size
print("Stack size:", len(stack))     # Output: 2
# Out:
# Stack size: 2

# %% [markdown]
# # Python Queues
#
# A **Queue** is a linear data structure that follows the **FIFO (First In, First Out)** principle. The element added first is the first one to be removed.
#
# ### Characteristics:
#
# * **FIFO Structure:** Elements are added at the rear (enqueue) and removed from the front (dequeue).
# * **Enqueue Operation:** Adding an element to the back of the queue.
# * **Dequeue Operation:** Removing an element from the front of the queue.
# * **Efficient Memory:** Using `collections.deque` provides fast $O(1)$ operations for both enqueue and dequeue.
#
# ---
#
# ### Core Operations (`collections.deque`):
#
# | Operation | Description |
# | :--- | :--- |
# | `append()` | Enqueue: Add an element to the rear |
# | `popleft()` | Dequeue: Remove and return the front element |
# | `[0]` | Peek at the front element without removing it |
# | `len()` | Check the total size of the queue |

# %% [markdown]
# Creation of Queue

# %%
from collections import deque

# Initialize an empty queue
queue = deque()

# %% [markdown]
# 1. append()

# %%
# 1. Enqueue (Add elements to the back)
queue.append("Customer 1")
queue.append("Customer 2")
queue.append("Customer 3")
print("Queue state:", list(queue))  # Output: ['Customer 1', 'Customer 2', 'Customer 3']
# Out:
# Queue state: ['Customer 1', 'Customer 2', 'Customer 3']

# %% [markdown]
# 2. [0]

# %%
# 2. Peek (Look at the front element)
front_element = queue[0]
print("Front element:", front_element)  # Output: Customer 1
# Out:
# Front element: Customer 1

# %% [markdown]
# 3. popleft()

# %%
# 3. Dequeue (Remove element from the front)
served = queue.popleft()
print("Served:", served)             # Output: Customer 1
print("Queue after dequeue:", list(queue))  # Output: ['Customer 2', 'Customer 3']
# Out:
# Served: Customer 1
# Queue after dequeue: ['Customer 2', 'Customer 3']

# %% [markdown]
# 4. len()

# %%
# 4. Check Queue size
print("Queue size:", len(queue))     # Output: 2
# Out:
# Queue size: 2

# %% [markdown]
# # Python Linked Lists
#
# A **Linked List** is a chain of connected items called **Nodes**.
#
# Each Node holds two things:
# 1. **Data:** The value itself.
# 2. **Next:** A pointer to the next item in the chain.
#
# ---
#
# ### Core Operations:
#
# | Operation | Description |
# | :--- | :--- |
# | `Node` | Creates an individual item holding data and a pointer |
# | `insert_head()` | Adds a new item to the very front of the chain |
# | `display()` | Walks through the chain and prints all items |

# %%
# Step 1: Create a single Node
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None  # Points to Nothing by default

# Step 2: Build the List
head = Node(10)          # First item:  10
head.next = Node(20)     # Second item: 20
head.next.next = Node(30)# Third item:  30

# Step 3: Print the List
temp = head
while temp:
    print(temp.data, end=" -> ")
    temp = temp.next
print("None")

# Output: 10 -> 20 -> 30 -> None
# Out:
# 10 -> 20 -> 30 -> None
