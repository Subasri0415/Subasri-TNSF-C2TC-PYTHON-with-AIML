# %% [markdown]
# <a href="https://colab.research.google.com/github/Subasri0415/Subasri-TNSF-C2TC-PYTHON-with-AIML/blob/main/MVIT_Batch_3%7C%7CAI_%26ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Day 1-Basics

# %%
#comment
print("Hello world")
# Out:
# Hello world

# %%
name="Subasri"
lastname="1"
print(name)
print (lastname)
print (type (name))
print (type (lastname))
# concatination
print (name + lastname)
# Out:
# Subasri
# 1
# <class 'str'>
# <class 'str'>
# Subasri1

# %%
# F string
name ="Subasri"
age = 22

print(f"My name is {name} and I am {age} years old")
# Out:
# My name is Subasri and I am 22 years old

# %%
# Typecasting

num1 = input (str)
num2 = input (int)
print(type(num1))
print(type(num2))
# Out:
# <class 'str'>Subasri
# <class 'int'>2004
# <class 'str'>
# <class 'str'>

# %%
#operators

#Arthimetic (addition)

a= 5
b= 7
print (a+b)
print(a-b)
print (a*b)
print(a/b)
print(a%b)
print(a**b)
print(a//b)
# Out:
# 12
# -2
# 35
# 0.7142857142857143
# 5
# 78125
# 0

# %%
# Comparision Operator

a = 5
b = 6
print (a>b)
print (a<b)
print (a==b)
print (a<=b)
print (a>=b)
# Out:
# False
# True
# False
# True
# False

# %%
# Logical Operator


# And prints true even one condition is true

a = 10
print (a > 5 and a < 20)

# OR prints true / false by only one condition
print (a > 5 and a > 20)
# Out:
# True
# False

# %%
# Assignment Operator

a = 5

print (a)
a += 5
print (a)
a -= 4
print (a)
a *=5
print (a)
a /= 5
print (a)
# Out:
# 5
# 10
# 6
# 30
# 6.0

# %%
# Membership operator

text = "Python"
print("P" in text)  # Case sensitive
print("p" in text)  # False

a = [1, 2]
b = a

print(a is b)
print(a is not b)
# Out:
# True
# False
# True
# False

# %%
# Conditional Statement
# if, elif, else

a = 5
b = 6

if a < b:
    print("Hello")
elif a > b:
    print("Okay")
else:
    print("Bye")
# Out:
# Hello

# %%
# Simple linear - Basic mathematical equation

x = int(input("Enter a value for x: "))

y = 2 * x + 3

print("The result for y is:", y)
# Out:
# Enter a value for x: 5
# The result for y is: 13

# %%
# Average

n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
n3 = int(input("Enter third number: "))
n4 = int(input("Enter fourth number: "))
n5 = int(input("Enter fifth number: "))

average = (n1 + n2 + n3 + n4 + n5) / 5

print("The average is:", average)
# Out:
# Enter first number: 23
# Enter second number: 45
# Enter third number: 26
# Enter fourth number: 39
# Enter fifth number: 40
# The average is: 34.6

# %%
# Threshold temperature

temp = float(input("Enter the temperature: "))

if temp > 30:
    print("Hot")
else:
    print("Normal")
# Out:
# Enter the temperature: 40
# Hot

# %%
# def is a keyword used to define a function.

def first(numbers_list):
    """
    A simple function that receives a list
    and returns its very first element.
    """
    if len(numbers_list) == 0:
        return "List is empty!"

    return numbers_list[0]

# %%
# Calling the function

my_numbers = [10, 20, 30, 40]

result = first(my_numbers)

print("The first element is:", result)
# Out:
# The first element is: 10

# %%
# ==========================================
# 1. HANDLING COMMON ERRORS (try-except-else-finally)
# ==========================================

def safe_divide(a, b):
    try:
        result = a / b

    except ZeroDivisionError as e:
        print(f"[ERROR CATCH]: Cannot divide by zero! Details: {e}")
        return None

    except TypeError as e:
        print(f"[ERROR CATCH]: Invalid input type! Details: {e}")
        return None

    else:
        print("[SUCCESS]: Division executed smoothly.")
        return result

    finally:
        print("[CLEANUP]: Division attempt finished.\n")


print("--- 1. Exception Handling ---")

safe_divide(10, 2)
safe_divide(10, 0)
safe_divide(10, "2")
# Out:
# --- 1. Exception Handling ---
# [SUCCESS]: Division executed smoothly.
# [CLEANUP]: Division attempt finished.
#
# [ERROR CATCH]: Cannot divide by zero! Details: division by zero
# [CLEANUP]: Division attempt finished.
#
# [ERROR CATCH]: Invalid input type! Details: unsupported operand type(s) for /: 'int' and 'str'
# [CLEANUP]: Division attempt finished.

# %%
# ==========================================
# 2. RAISING CUSTOM EXCEPTIONS
# ==========================================

class InvalidAgeError(Exception):
    """Custom Exception for invalid age inputs."""
    pass


def verify_voter_age(age):
    if age < 0:
        raise InvalidAgeError("Age cannot be negative!")

    elif age < 18:
        raise InvalidAgeError("User must be at least 18 years old to vote.")

    else:
        print("Access granted: Eligible to vote!")


print("--- 2. Custom Errors ---")

try:
    verify_voter_age(15)

except InvalidAgeError as e:
    print(f"[CUSTOM ERROR CATCH]: {e}\n")
# Out:
# --- 2. Custom Errors ---
# [CUSTOM ERROR CATCH]: User must be at least 18 years old to vote.
